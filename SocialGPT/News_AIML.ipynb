# %% [markdown]
# Shreya: I talked to Viraaji and the graph we create should be from data of Tesla and First Repulic Bank, for now. Let's do our tests accordingly. Will work on the neetworkx part tomorrow morning EST.
#
# Plan:
# All our resulting data/network graph needs to be sent to the JP team. Thanks!
#
# Thanks for the update Shreya :)

# %%
# !pip install transformers
# !pip install sentencepiece
# !pip install datasets
# !pip install GoogleNews
# !pip install feedparser
# !pip install feedsearch
# !pip install newspaper3k
# Out:
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#                                               0.0/7.2 MB ? eta -:--:--
#      -                                        0.3/7.2 MB 7.1 MB/s eta 0:00:01
#      ----                                     0.8/7.2 MB 8.7 MB/s eta 0:00:01
#      -------                                  1.4/7.2 MB 10.1 MB/s eta 0:00:01
#      -----------                              2.0/7.2 MB 10.7 MB/s eta 0:00:01
#      ------------                             2.2/7.2 MB 11.0 MB/s eta 0:00:01
#      ------------                             2.2/7.2 MB 11.0 MB/s eta 0:00:01
#      -------------------                      3.5/7.2 MB 10.6 MB/s eta 0:00:01
#      ----------------------                   4.1/7.2 MB 10.8 MB/s eta 0:00:01
#      --------------------------               4.7/7.2 MB 11.2 MB/s eta 0:00:01
#      -----------------------------            5.3/7.2 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------        6.0/7.2 MB 11.7 MB/s eta 0:00:01
#      ------------------------------------     6.6/7.2 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------------  7.2/7.2 MB 12.1 MB/s eta 0:00:01
#      ---------------------------------------- 7.2/7.2 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from transformers) (3.12.1)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#                                               0.0/236.8 kB ? eta -:--:--
#      ------------------------------------- 236.8/236.8 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from transformers) (6.0)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2023.6.3-cp311-cp311-win_amd64.whl (268 kB)
#                                               0.0/268.0 kB ? eta -:--:--
#      ------------------------------------- 268.0/268.0 kB 17.2 MB/s eta 0:00:00
# Collecting requests (from transformers)
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#                                               0.0/62.6 kB ? eta -:--:--
#      ---------------------------------------- 62.6/62.6 kB ? eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp311-cp311-win_amd64.whl (3.5 MB)
#                                               0.0/3.5 MB ? eta -:--:--
#      -------                                  0.7/3.5 MB 13.9 MB/s eta 0:00:01
#      --------------                           1.3/3.5 MB 16.1 MB/s eta 0:00:01
#      ----------------------                   1.9/3.5 MB 13.6 MB/s eta 0:00:01
#      ------------------------------           2.7/3.5 MB 14.1 MB/s eta 0:00:01
#      ------------------------------------     3.2/3.5 MB 13.4 MB/s eta 0:00:01
#      ---------------------------------------- 3.5/3.5 MB 13.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp311-cp311-win_amd64.whl (263 kB)
#                                               0.0/263.7 kB ? eta -:--:--
#      -------------------------------------- 263.7/263.7 kB 8.2 MB/s eta 0:00:00
# Collecting tqdm>=4.27 (from transformers)
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#                                               0.0/77.1 kB ? eta -:--:--
#      ---------------------------------------- 77.1/77.1 kB 4.5 MB/s eta 0:00:00
# Collecting fsspec (from huggingface-hub<1.0,>=0.14.1->transformers)
#   Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#                                               0.0/163.8 kB ? eta -:--:--
#      -------------------------------------- 163.8/163.8 kB 9.6 MB/s eta 0:00:00
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub<1.0,>=0.14.1->transformers)
#   Downloading typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Requirement already satisfied: colorama in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading charset_normalizer-3.1.0-cp311-cp311-win_amd64.whl (96 kB)
#                                               0.0/96.7 kB ? eta -:--:--
#      ---------------------------------------- 96.7/96.7 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (3.4)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading urllib3-2.0.3-py3-none-any.whl (123 kB)
#                                               0.0/123.6 kB ? eta -:--:--
#      ---------------------------------------- 123.6/123.6 kB ? eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests->transformers)
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#                                               0.0/157.0 kB ? eta -:--:--
#      -------------------------------------- 157.0/157.0 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: tokenizers, safetensors, urllib3, typing-extensions, tqdm, regex, fsspec, charset-normalizer, certifi, requests, huggingface-hub, transformers
# Successfully installed certifi-2023.5.7 charset-normalizer-3.1.0 fsspec-2023.6.0 huggingface-hub-0.15.1 regex-2023.6.3 requests-2.31.0 safetensors-0.3.1 tokenizers-0.13.3 tqdm-4.65.0 transformers-4.30.2 typing-extensions-4.6.3 urllib3-2.0.3
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp311-cp311-win_amd64.whl (977 kB)
#                                               0.0/977.5 kB ? eta -:--:--
#      -------                                204.8/977.5 kB 6.3 MB/s eta 0:00:01
#      ----------------------------           737.3/977.5 kB 9.3 MB/s eta 0:00:01
#      -------------------------------------- 977.5/977.5 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99
# Collecting datasets
#   Downloading datasets-2.13.0-py3-none-any.whl (485 kB)
#                                               0.0/485.6 kB ? eta -:--:--
#      --------------------------------       409.6/485.6 kB 8.5 MB/s eta 0:00:01
#      ------------------------------------- 485.6/485.6 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from datasets) (1.24.3)
# Collecting pyarrow>=8.0.0 (from datasets)
#   Downloading pyarrow-12.0.1-cp311-cp311-win_amd64.whl (21.5 MB)
#                                               0.0/21.5 MB ? eta -:--:--
#                                               0.4/21.5 MB 7.4 MB/s eta 0:00:03
#      -                                        1.0/21.5 MB 12.3 MB/s eta 0:00:02
#      --                                       1.6/21.5 MB 12.8 MB/s eta 0:00:02
#      ---                                      2.1/21.5 MB 12.3 MB/s eta 0:00:02
#      -----                                    2.9/21.5 MB 13.0 MB/s eta 0:00:02
#      ------                                   3.5/21.5 MB 13.2 MB/s eta 0:00:02
#      -------                                  4.2/21.5 MB 13.3 MB/s eta 0:00:02
#      ---------                                4.9/21.5 MB 13.5 MB/s eta 0:00:02
#      ----------                               5.5/21.5 MB 13.5 MB/s eta 0:00:02
#      -----------                              6.2/21.5 MB 13.6 MB/s eta 0:00:02
#      ------------                             6.6/21.5 MB 13.3 MB/s eta 0:00:02
#      -------------                            7.3/21.5 MB 13.3 MB/s eta 0:00:02
#      --------------                           7.9/21.5 MB 13.3 MB/s eta 0:00:02
#      ---------------                          8.6/21.5 MB 13.4 MB/s eta 0:00:01
#      -----------------                        9.3/21.5 MB 13.5 MB/s eta 0:00:01
#      ------------------                       9.9/21.5 MB 13.5 MB/s eta 0:00:01
#      -------------------                     10.5/21.5 MB 13.6 MB/s eta 0:00:01
#      --------------------                    11.2/21.5 MB 13.6 MB/s eta 0:00:01
#      ---------------------                   11.7/21.5 MB 13.9 MB/s eta 0:00:01
#      ----------------------                  12.4/21.5 MB 13.9 MB/s eta 0:00:01
#      -----------------------                 13.1/21.5 MB 13.9 MB/s eta 0:00:01
#      -------------------------               13.8/21.5 MB 14.2 MB/s eta 0:00:01
#      --------------------------              14.5/21.5 MB 14.2 MB/s eta 0:00:01
#      ---------------------------             14.9/21.5 MB 14.2 MB/s eta 0:00:01
#      ---------------------------             14.9/21.5 MB 14.2 MB/s eta 0:00:01
#      ------------------------------          16.7/21.5 MB 14.2 MB/s eta 0:00:01
#      -------------------------------         17.3/21.5 MB 14.6 MB/s eta 0:00:01
#      --------------------------------        18.0/21.5 MB 14.9 MB/s eta 0:00:01
#      ----------------------------------      18.7/21.5 MB 14.9 MB/s eta 0:00:01
#      -----------------------------------     19.5/21.5 MB 14.9 MB/s eta 0:00:01
#      ------------------------------------    20.1/21.5 MB 14.9 MB/s eta 0:00:01
#      -------------------------------------   20.8/21.5 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  21.5/21.5 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------  21.5/21.5 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------- 21.5/21.5 MB 13.4 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#                                               0.0/110.5 kB ? eta -:--:--
#      -------------------------------------- 110.5/110.5 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp311-cp311-win_amd64.whl (30 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#                                               0.0/134.3 kB ? eta -:--:--
#      -------------------------------------- 134.3/134.3 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from datasets) (2023.6.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp311-cp311-win_amd64.whl (317 kB)
#                                               0.0/317.2 kB ? eta -:--:--
#      -------------------------------------- 317.2/317.2 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from datasets) (0.15.1)
# Requirement already satisfied: packaging in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets) (3.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp311-cp311-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp311-cp311-win_amd64.whl (60 kB)
#                                               0.0/60.2 kB ? eta -:--:--
#      ---------------------------------------- 60.2/60.2 kB ? eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp311-cp311-win_amd64.whl (32 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: filelock in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->datasets) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, pyarrow, multidict, frozenlist, dill, async-timeout, yarl, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.13.0 dill-0.3.6 frozenlist-1.3.3 multidict-6.0.4 multiprocess-0.70.14 pyarrow-12.0.1 xxhash-3.2.0 yarl-1.9.2
# Collecting GoogleNews
#   Downloading GoogleNews-1.6.8-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from GoogleNews) (4.12.2)
# Collecting dateparser (from GoogleNews)
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
#                                               0.0/293.8 kB ? eta -:--:--
#      ---------------                        122.9/293.8 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 293.8/293.8 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from GoogleNews) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->GoogleNews) (2.4.1)
# Requirement already satisfied: pytz in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from dateparser->GoogleNews) (2023.3)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from dateparser->GoogleNews) (2023.6.3)
# Collecting tzlocal (from dateparser->GoogleNews)
#   Downloading tzlocal-5.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: six>=1.5 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil->GoogleNews) (1.16.0)
# Requirement already satisfied: tzdata in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from tzlocal->dateparser->GoogleNews) (2023.3)
# Installing collected packages: tzlocal, dateparser, GoogleNews
# Successfully installed GoogleNews-1.6.8 dateparser-1.1.8 tzlocal-5.0.1
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#                                               0.0/81.1 kB ? eta -:--:--
#      ---------------------------------------- 81.1/81.1 kB 4.4 MB/s eta 0:00:00
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (pyproject.toml): started
#   Building wheel for sgmllib3k (pyproject.toml): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6060 sha256=8e6b561850cf6bdd8e082574693d61de22861e5bd50bb629724c0599b11d579f
#   Stored in directory: c:\users\jordi\appdata\local\pip\cache\wheels\3b\25\2a\105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.10 sgmllib3k-1.0.0
# Collecting feedsearch
#   Downloading feedsearch-1.0.12-py35.py36.py37-none-any.whl (18 kB)
# Requirement already satisfied: requests in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from feedsearch) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from feedsearch) (4.12.2)
# Requirement already satisfied: feedparser in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from feedsearch) (6.0.10)
# Collecting click (from feedsearch)
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#                                               0.0/96.6 kB ? eta -:--:--
#      ---------------------------------------- 96.6/96.6 kB 1.8 MB/s eta 0:00:00
# Collecting Werkzeug (from feedsearch)
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#                                               0.0/242.5 kB ? eta -:--:--
#      ------------------------------------- 242.5/242.5 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->feedsearch) (2.4.1)
# Requirement already satisfied: colorama in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from click->feedsearch) (0.4.6)
# Requirement already satisfied: sgmllib3k in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from feedparser->feedsearch) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests->feedsearch) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests->feedsearch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests->feedsearch) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests->feedsearch) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from Werkzeug->feedsearch) (2.1.3)
# Installing collected packages: Werkzeug, click, feedsearch
# Successfully installed Werkzeug-2.3.6 click-8.1.3 feedsearch-1.0.12
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#                                               0.0/211.1 kB ? eta -:--:--
#      -------------------------------------- 211.1/211.1 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from newspaper3k) (4.12.2)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from newspaper3k) (9.5.0)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from newspaper3k) (6.0)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting lxml>=3.6.0 (from newspaper3k)
#   Downloading lxml-4.9.2-cp311-cp311-win_amd64.whl (3.8 MB)
#                                               0.0/3.8 MB ? eta -:--:--
#      ----                                     0.5/3.8 MB 13.8 MB/s eta 0:00:01
#      -----------                              1.0/3.8 MB 13.1 MB/s eta 0:00:01
#      -----------------                        1.6/3.8 MB 12.9 MB/s eta 0:00:01
#      ------------------------                 2.3/3.8 MB 13.2 MB/s eta 0:00:01
#      ------------------------------           2.9/3.8 MB 13.2 MB/s eta 0:00:01
#      -------------------------------------    3.5/3.8 MB 13.2 MB/s eta 0:00:01
#      ---------------------------------------- 3.8/3.8 MB 12.6 MB/s eta 0:00:00
# Collecting nltk>=3.2.1 (from newspaper3k)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#                                               0.0/1.5 MB ? eta -:--:--
#      ------------------                       0.7/1.5 MB 14.4 MB/s eta 0:00:01
#      ------------------------------------     1.4/1.5 MB 14.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.10.0 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from newspaper3k) (2.31.0)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from newspaper3k) (6.0.10)
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-3.4.4-py3-none-any.whl (93 kB)
#                                               0.0/93.3 kB ? eta -:--:--
#      ---------------------------------------- 93.3/93.3 kB ? eta 0:00:00
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#                                               0.0/7.4 MB ? eta -:--:--
#      --                                       0.5/7.4 MB 17.2 MB/s eta 0:00:01
#      -----                                    1.1/7.4 MB 13.9 MB/s eta 0:00:01
#      -------                                  1.4/7.4 MB 14.3 MB/s eta 0:00:01
#      -------                                  1.5/7.4 MB 8.5 MB/s eta 0:00:01
#      -----------------                        3.2/7.4 MB 14.4 MB/s eta 0:00:01
#      --------------------                     3.9/7.4 MB 14.6 MB/s eta 0:00:01
#      ------------------------                 4.5/7.4 MB 14.5 MB/s eta 0:00:01
#      ----------------------------             5.2/7.4 MB 14.6 MB/s eta 0:00:01
#      --------------------------------         6.0/7.4 MB 14.8 MB/s eta 0:00:01
#      ------------------------------------     6.8/7.4 MB 15.0 MB/s eta 0:00:01
#      ---------------------------------------  7.4/7.4 MB 14.8 MB/s eta 0:00:01
#      ---------------------------------------  7.4/7.4 MB 14.8 MB/s eta 0:00:01
#      ---------------------------------------- 7.4/7.4 MB 13.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from newspaper3k) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: soupsieve>1.2 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.4.1)
# Requirement already satisfied: six in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.2.1->newspaper3k) (8.1.3)
# Requirement already satisfied: joblib in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2023.6.3)
# Requirement already satisfied: tqdm in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.10.0->newspaper3k) (2023.5.7)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.12.1)
# Requirement already satisfied: colorama in c:\users\jordi\appdata\local\programs\python\python311\lib\site-packages (from click->nltk>=3.2.1->newspaper3k) (0.4.6)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k
#   Building wheel for tinysegmenter (pyproject.toml): started
#   Building wheel for tinysegmenter (pyproject.toml): finished with status 'done'
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13568 sha256=59383cd125209a369b3b6cb35bd347804ad627a45dbaf5816871ef938fa2d987
#   Stored in directory: c:\users\jordi\appdata\local\pip\cache\wheels\fc\ab\f8\cce3a9ae6d828bd346be695f7ff54612cd22b7cbd7208d68f3
#   Building wheel for feedfinder2 (pyproject.toml): started
#   Building wheel for feedfinder2 (pyproject.toml): finished with status 'done'
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3359 sha256=eda217a81134f662d5471b5d9d9fde11277e57df78e638687511d2b82c592c3b
#   Stored in directory: c:\users\jordi\appdata\local\pip\cache\wheels\80\d5\72\9cd9eccc819636436c6a6e59c22a0fb1ec167beef141f56491
#   Building wheel for jieba3k (pyproject.toml): started
#   Building wheel for jieba3k (pyproject.toml): finished with status 'done'
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398388 sha256=c00b0d0ecd2cb4906faa735d0d8e5274a369361cfcebcf40fbb674f600ceb429
#   Stored in directory: c:\users\jordi\appdata\local\pip\cache\wheels\3a\a1\46\8e68055c1713f9c4598774c15ad0541f26d5425ee7423b6493
# Successfully built tinysegmenter feedfinder2 jieba3k
# Installing collected packages: tinysegmenter, jieba3k, lxml, cssselect, requests-file, nltk, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.2.0 feedfinder2-0.0.4 jieba3k-0.35.1 lxml-4.9.2 newspaper3k-0.2.8 nltk-3.8.1 requests-file-1.5.1 tinysegmenter-0.3 tldextract-3.4.4

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification, AutoModelForSeq2SeqLM
from GoogleNews import GoogleNews

from feedsearch import search
import feedparser
import time
import newspaper
import json
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %% [markdown]
# Some random articles for testing

# %%
ARTICLE = """ LONDON, England (Reuters) -- Harry Potter star Daniel Radcliffe gains access to a reported £20 million ($41.1 million) fortune as he turns 18 on Monday, but he insists the money won't cast a spell on him. Daniel Radcliffe as Harry Potter in "Harry Potter and the Order of the Phoenix" To the disappointment of gossip columnists around the world, the young actor says he has no plans to fritter his cash away on fast cars, drink and celebrity parties. "I don't plan to be one of those people who, as soon as they turn 18, suddenly buy themselves a massive sports car collection or something similar," he told an Australian interviewer earlier this month. "I don't think I'll be particularly extravagant. "The things I like buying are things that cost about 10 pounds -- books and CDs and DVDs." At 18, Radcliffe will be able to gamble in a casino, buy a drink in a pub or see the horror film "Hostel: Part II," currently six places below his number one movie on the UK box office chart. Details of how he'll mark his landmark birthday are under wraps. His agent and publicist had no comment on his plans. "I'll definitely have some sort of party," he said in an interview. "Hopefully none of you will be reading about it." Radcliffe's earnings from the first five Potter films have been held in a trust fund which he has not been able to touch. Despite his growing fame and riches, the actor says he is keeping his feet firmly on the ground. "People are always looking to say 'kid star goes off the rails,'" he told reporters last month. "But I try very hard not to go that way because it would be too easy for them." His latest outing as the boy wizard in "Harry Potter and the Order of the Phoenix" is breaking records on both sides of the Atlantic and he will reprise the role in the last two films. Watch I-Reporter give her review of Potter's latest » . There is life beyond Potter, however. The Londoner has filmed a TV movie called "My Boy Jack," about author Rudyard Kipling and his son, due for release later this year. He will also appear in "December Boys," an Australian film about four boys who escape an orphanage. Earlier this year, he made his stage debut playing a tortured teenager in Peter Shaffer's "Equus." Meanwhile, he is braced for even closer media scrutiny now that he's legally an adult: "I just think I'm going to be more sort of fair game," he told Reuters. E-mail to a friend . Copyright 2007 Reuters. All rights reserved.This material may not be published, broadcast, rewritten, or redistributed."""

# %%
ARTICLE = '''Elon Musk is being accused of insider trading in a proposed class action by investors accusing the Tesla Inc CEO of manipulating the cryptocurrency Dogecoin, costing them billions of dollars.
In a Wednesday night filing in Manhattan federal court, investors said Musk used Twitter posts, paid online influencers, his 2021 appearance on NBC's "Saturday Night Live" and other "publicity stunts" to trade profitably at their expense through several Dogecoin wallets that he or Tesla controls.
Investors said this included when Musk sold about $124 million of Dogecoin in April after he replaced Twitter's blue bird logo with Dogecoin's Shiba Inu dog logo, leading to a 30% jump in Dogecoin's price.
A "deliberate course of carnival barking, market manipulation and insider trading" enabled Musk to defraud investors, promote himself and his companies, the filing said.'''

# %%
ARTICLE = ''''Jamie Dimon said in June that he was preparing the bank for an economic "hurricane" caused by the Federal Reserve and Russia's war in Ukraine. Al Drago | Bloomberg | Getty Images

JPMorgan Chase on Thursday shut down the website for a college financial aid platform it bought for $175 million after alleging the company's founder created nearly 4 million fake customer accounts. The country's biggest bank acquired Frank in September 2021 to help it deepen relationships with college students, a key demographic, a Chase executive told CNBC at the time. JPMorgan touted the deal as giving it the "fastest-growing college financial planning platform" used by more than 5 million students at 6,000 institutions. It also provided access to the startup's founder, Charlie Javice, who joined the New York-based bank as part of the acquisition. Months after the transaction closed, JPMorgan said it learned the truth after sending out marketing emails to a batch of 400,000 Frank customers. About 70% of the emails bounced back, the bank said in a lawsuit filed last month in federal court. Javice, who had approached JPMorgan in mid-2021 about a potential sale, lied to the bank about her startup's scale, the bank alleged. Specifically, after being pressed for confirmation of Frank's customer base during the due diligence process, Javice used a data scientist to invent millions of fake accounts, according to JPMorgan.

watch now

"To cash in, Javice decided to lie, including lying about Frank's success, Frank's size, and the depth of Frank's market penetration in order to induce JPMC to purchase Frank for $175 million," the bank said. "Javice represented in documents placed in the acquisition data room, in pitch materials, and through verbal presentations [that] more than 4.25 million students had created Frank accounts." Instead of gaining a business with 4.25 million students, JPMorgan had one with "fewer than 300,000 customers," JPMorgan said in the suit.

Frank emails

In the suit, JPMorgan alleged that Javice first asked her engineering chief to create "fake customer details" using algorithms. When he refused, she found a data science professor at a New York-area college to create the accounts, the lender said. The bank included incriminating emails between the unnamed professor and Javice in its suit. For instance, Javice had allegedly asked the professor, "Will the fake emails look real with an eye check or better to use unique ID?" JPMorgan had access to the emails because it had acquired Frank's technology systems as part of the acquisition, according to a person with knowledge of the situation.

Javice's defense

A lawyer for Javice told The Wall Street Journal that JPMorgan had "manufactured" reasons to fire her late last year to avoid paying millions of dollars owed to her. Javice has sued JPMorgan, saying the bank should front legal bills she incurred during its internal investigations. "After JPM rushed to acquire Charlie's rocketship business, JPM realized they couldn't work around existing student privacy laws, committed misconduct and then tried to retrade the deal," attorney Alex Spiro told the Journal. "Charlie blew the whistle and then sued." Spiro, a partner at Quinn Emanuel, didn't immediately return a call from CNBC. JPMorgan spokesman Pablo Rodriguez had this response: "Our legal claims against Ms. Javice and Mr. Amar are set out in our complaint, along with the key facts," he said. "Ms. Javice was not and is not a whistleblower. Any dispute will be resolved through the legal process."

The alleged fraud perpetrated by Javice and one of her executives "materially damaged JPMC in an amount to be proven at trial, but not less than $175 million," JPMorgan said in its suit. Regardless of the outcome of this legal scuffle, this is an embarrassing episode for JPMorgan and its CEO, Jamie Dimon. In a bid to fend off encroaching competitors, JPMorgan has gone on a buying spree of fintech companies in recent years, and Dimon has repeatedly defended his technology investments as necessary ones that will yield good returns. The fact that a young founder in an industry known for shaky metrics and a "fake it 'til you make it" ethos managed to allegedly dupe JPMorgan calls into question how stringent the bank's due diligence process is. In an interview at the time of the deal, Javice marveled at how far she had come in just a few years leading her startup. "Today is my first day employed by someone else, ever," Javice told CNBC. "I mean it still feels very much like, pinch me, did this really happen?" As a result of the legal scuffle, JPMorgan shut down Frank early Thursday morning. "Frank is no longer available" the website now reads. "To file your Free Application for Federal Student Aid (FAFSA), visit StudentAid.gov."'''

# %% [markdown]
# **Keyword-extractor**

# %%
## Loading the bert model and tokenizer for NER
ky_model = "dslim/bert-base-NER-uncased" #"yanekyuk/bert-uncased-keyword-extractor"

tokenizer = AutoTokenizer.from_pretrained(ky_model)
model = AutoModelForTokenClassification.from_pretrained(ky_model)

nlp = pipeline("ner", model=model, tokenizer=tokenizer,aggregation_strategy="first")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
def extract_keywords(text):
    """
    Extract keywords and construct them back from tokens
    """
    result = list()
    keyword = ""
    for token in nlp(text):
        print(token['word'],token['entity_group'])
        # if token['entity'] == 'I-KEY':
        #     keyword += token['word'][2:] if \
        #       token['word'].startswith("##") else f" {token['word']}"
        # else:
        #     if keyword:
        #         result.append(keyword)
        #     keyword = token['word']
    # Add the last keyword
    result.append(keyword)
    # return result
    return list(set(result))

# %%
extract_keywords(ARTICLE)
# Out:
# jamie dimon PER
# federal reserve ORG
# russia LOC
# ukraine LOC
# al drago PER
# bloomberg ORG
# getty ORG
# jpmorgan chase ORG
# frank PER
# chase ORG
# cnbc ORG
# jpmorgan ORG
# charlie javice PER
# new york MISC
# jpmorgan ORG
# frank ORG
# javice PER
# jpmorgan ORG
# frank PER
# javice PER
# jpmorgan ORG
# javice PER
# frank PER
# frank PER
# frank PER
# jpmc ORG
# frank PER
# javice PER
# jpmorgan ORG
# jpmorgan ORG
# frank ORG
# jpmorgan ORG
# javice PER
# new MISC
# york LOC
# javice PER
# ja PER
# ['']

# %% [markdown]
# News Summary

# %%
## Loading the pegasus model for summarization
summarization_model = 'google/pegasus-cnn_dailymail'
model = AutoModelForSeq2SeqLM.from_pretrained(summarization_model)
tokenizer = AutoTokenizer.from_pretrained(summarization_model)

def summarize_article(text):

  tokens_input = tokenizer.encode("summarize: "+ text, return_tensors='pt', max_length=1024, truncation=True)
  ids = model.generate(tokens_input, min_length=80, max_length=120)
  summary = tokenizer.decode(ids[0], skip_special_tokens=True)

  return summary.split('<n>')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/88.0 [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]

# %%
summarize_article(ARTICLE)
# Out:
# ['JPMorgan Chase shut down the website for a college financial aid platform it bought for $175 million.',
#  "The country's biggest bank acquired Frank in September 2021 to help it deepen relationships with college students.",
#  "It also provided access to the startup's founder, Charlie Javice.",
#  'Months after the transaction closed, JPMorgan said it learned the truth after sending out marketing emails to 400,000 Frank customers.']

# %% [markdown]
# **News Dataset generation**

# %%
## To scrape complete news articles from links
def get_news_article_from_link(url):

  article = newspaper.Article(url=url, language='en')
  article.download()
  article.parse()

  return str(article.text)

# %%
 ## Using googlenews to generate links for a given ticker for last 365 days
 ## Google is blocking incase trying to scrape more than 10 links at one go

googlenews = GoogleNews()

googlenews.set_lang('en')
googlenews.set_period('365d')
# googlenews.set_time_range('06/01/2022','06/12/2023')
googlenews.set_encode('utf-8')

googlenews.search('TESLA')

link_count = googlenews.total_count()

print(googlenews)
print(link_count)
# result2 = googlenews.page_at(2)
googleresult = googlenews.result(sort=True)
for gr in googleresult:
  print(gr['media'])
# for p in range(2, link_count//10):
# for p in range(2, 10):
#   googleresult.append(googlenews.page_at(p))
#   time.sleep(2)
# Out:
# <GoogleNews.GoogleNews object at 0x7fe7f18fe200>
# 59600000
# Investor's Business Daily
# Fox Business
# Reuters
# Barron's
# Daily Mail
# Barron's
# Yahoo Finance
# TheStreet
# TechCrunch
# Drive Tesla

# %%
import requests
import json
import io
import urllib.parse
from time import sleep
import re

# %%
## NYTimes News API: 500 requests per day and 5 requests per minute
## Only month-specific archive available. Need to iterate through months and filter out articles based on keywords

def get_nyt_news_links():
    nyt_api_key='KGhY6kRC25qTeWd16RC0bkRCEQ1LWLSK'
    nyt_res = list()
    q = r'tesla|(first.*republic)'
    year = 2022
    
    for month in range(6, 13):
        nyt = requests.get(f"https://api.nytimes.com/svc/archive/v1/{year}/{month}.json?api-key={nyt_api_key}")
        nyt_data = nyt.json()
        for i in range(0, len(nyt_data['response']['docs'])):
            url = nyt_data['response']['docs'][i]['web_url']
            abstract = nyt_data['response']['docs'][i]['abstract']
            if "youtube" in url:
                continue
            if re.search(q, url, re.IGNORECASE) or re.search(q, abstract, re.IGNORECASE):
                nyt_res.append(url)
        sleep(12)

    print(len(nyt_res)) # 2022 done
    year = 2023
    
    for month in range(1, 7):
        nyt = requests.get(f"https://api.nytimes.com/svc/archive/v1/{year}/{month}.json?api-key={nyt_api_key}")
        nyt_data = nyt.json()
        for i in range(0, len(nyt_data['response']['docs'])):
            url = nyt_data['response']['docs'][i]['web_url']
            abstract = nyt_data['response']['docs'][i]['abstract']
            if "youtube" in url:
                continue
            if re.search(q, url, re.IGNORECASE) or re.search(q, abstract, re.IGNORECASE):
                nyt_res.append(url)
        sleep(12)

    print(len(nyt_res)) # 2023 done
    return nyt_res

# %%
nyt_res = get_nyt_news_links()
print(*nyt_res[:10], sep='\n')
get_news_article_from_link(nyt_res[0]) # test
# Out:
# 33
# 97
# https://www.nytimes.com/2022/06/01/opinion/technology/elon-musk-tesla-twitter.html
# https://www.nytimes.com/2022/06/01/technology/elon-musk-tesla-spacex-office.html
# https://www.nytimes.com/2022/06/03/business/tesla-elon-musk-job-cuts.html
# https://www.nytimes.com/2022/06/08/technology/tesla-autopilot-safety-data.html
# https://www.nytimes.com/2022/06/09/business/tesla-autopilot-nhtsa-investigation.html
# https://www.nytimes.com/2022/06/12/business/the-week-in-business-trouble-for-tesla.html
# https://www.nytimes.com/2022/06/21/business/tesla-online-sales-dealerships.html
# https://www.nytimes.com/2022/06/27/business/dealbook/elon-musk-tesla-ceo-pay.html
# https://www.nytimes.com/2022/07/02/business/tesla-q2-sales.html
# https://www.nytimes.com/2022/07/20/business/tesla-earnings-elon-musk.html
# 'This is the fundamental weakness of every organization run as a cult of personality: The dear leader can’t be everywhere or make every decision but often fails to provide the clear code of values that allows managers to independently shape their decisions around common goals. When the success of the company is tied to one man’s whims, you get bizarre phenomena like managers deciding whether or not to take issues to Mr. Musk based on the shade of blond of his wife’s hair that day (with platinum shades being correlated with better moods).\n\nWhen the boss happens to run tunneling, rocket and brain-implant companies in addition to a high-profile car company, even the most brilliant minds will occasionally be too disconnected from the realities of the decisions that they must make. After the collapses of Theranos and WeWork — companies with similarly confident founders who insisted that they would achieve their soaring ambitions if given more time and money — Mr. Musk’s reliance on hype is especially jarring.\n\nIndeed, the main difference between Mr. Musk and Silicon Valley’s fallen heroes is that he has been able to deliver on some promises: Tesla does make cars, and SpaceX does land rockets. But as a number of old promises like fully self-driving cars appear to be more aspirational and less plausible, the distinction between him and those fallen heroes is starting to lose its meaning. His long list of unfulfilled commitments — a fully solar-powered electric vehicle charging network, a fully automated manufacturing system, an autonomous minibus and even a rocket-powered flying car — wildly exceed his achievements.\n\nBy moving to buy Twitter, Mr. Musk has not only added another distraction to his long list but has also already shown the same drive to announce sweeping decisions in public. While he had some success in realizing user features at Tesla, his contradictory goals of increasing algorithmic transparency and eliminating spam bots on Twitter are the most obvious sign that he intends to impose his will on the service without drawing on the expertise of workers who have been wrestling with Twitter’s thorniest challenges.\n\nUltimately Mr. Musk’s goals for Twitter, as they are for Tesla, are not about making the right decisions for his companies or the people who make them possible. They are about playing to the crowd and burnishing the legend that keeps fresh bodies and minds moving through the businesses that chew them up and spit them out. Now if Twitter falls into his control, Mr. Musk will have seized the means of making the product he has always cared about most: his own myth making.'

# %%
## The Guardian News API
## Lets us select query and date range
## Need to iterate through dynamic-size pages

def get_gdn_news_links():
    q='tesla OR (first AND republic)'
    gdn_api_key='45c365a2-5c56-4144-8b1f-9a5554f267bb'
    from_date = '2022-06-01'
    to_date = '2023-06-13'
    gdn_res = list()

    gdn = requests.get(f"https://content.guardianapis.com/search?q={urllib.parse.quote(q)}&from-date={from_date}&to-date={to_date}&api-key={gdn_api_key}")
    gdn_data = gdn.json()
    # print(gdn.json())
    pages = gdn_data['response']['pages']

    for page in range(1,pages+1):
        gdn = requests.get(f"https://content.guardianapis.com/search?page={page}&q={urllib.parse.quote(q)}&from-date={from_date}&api-key={gdn_api_key}")
        gdn_data = gdn.json()
        for i in range(len(gdn_data['response']['results'])):
            url = gdn_data['response']['results'][i]['webUrl']
            if "youtube" in url:
                continue
            gdn_res.append(url)
        
    print(len(gdn_res))
    return gdn_res

# %%
gdn_res = get_gdn_news_links()
print(*gdn_res[:10],sep='\n')
get_news_article_from_link(gdn_res[0]) # test
# Out:
# {'response': {'status': 'ok', 'userTier': 'developer', 'total': 2082, 'startIndex': 1, 'pageSize': 10, 'currentPage': 1, 'pages': 209, 'orderBy': 'relevance', 'results': [{'id': 'us-news/2023/mar/17/first-thing-markets-on-alert-after-us-banks-join-forces-to-rescue-first-republic', 'type': 'article', 'sectionId': 'us-news', 'sectionName': 'US news', 'webPublicationDate': '2023-03-17T10:24:10Z', 'webTitle': 'Markets on alert after US banks join forces to rescue First Republic | First Thing', 'webUrl': 'https://www.theguardian.com/us-news/2023/mar/17/first-thing-markets-on-alert-after-us-banks-join-forces-to-rescue-first-republic', 'apiUrl': 'https://content.guardianapis.com/us-news/2023/mar/17/first-thing-markets-on-alert-after-us-banks-join-forces-to-rescue-first-republic', 'isHosted': False, 'pillarId': 'pillar/news', 'pillarName': 'News'}, {'id': 'business/2023/apr/28/fed-silicon-valley-bank-collapse-report', 'type': 'article', 'sectionId': 'business', 'sectionName': 'Business', 'webPublicationDate': '2023-04-28T21:27:12Z', 'webTitle': 'US banking crisis: federal body prepares to put First Republic into receivership', 'webUrl': 'https://www.theguardian.com/business/2023/apr/28/fed-silicon-valley-bank-collapse-report', 'apiUrl': 'https://content.guardianapis.com/business/2023/apr/28/fed-silicon-valley-bank-collapse-report', 'isHosted': False, 'pillarId': 'pillar/news', 'pillarName': 'News'}, {'id': 'business/2023/apr/25/first-republic-bank-shares-fall', 'type': 'article', 'sectionId': 'business', 'sectionName': 'Business', 'webPublicationDate': '2023-04-25T22:34:15Z', 'webTitle': 'First Republic Bank shares fall 50% after reporting dramatic slump in deposits', 'webUrl': 'https://www.theguardian.com/business/2023/apr/25/first-republic-bank-shares-fall', 'apiUrl': 'https://content.guardianapis.com/business/2023/apr/25/first-republic-bank-shares-fall', 'isHosted': False, 'pillarId': 'pillar/news', 'pillarName': 'News'}, {'id': 'business/2023/apr/30/time-running-out-for-us-financial-firms-to-bid-for-ailing-bank-first-republic', 'type': 'article', 'sectionId': 'business', 'sectionName': 'Business', 'webPublicationDate': '2023-04-30T16:58:59Z', 'webTitle': 'Time running out for US financial firms to bid for ailing bank First Republic', 'webUrl': 'https://www.theguardian.com/business/2023/apr/30/time-running-out-for-us-financial-firms-to-bid-for-ailing-bank-first-republic', 'apiUrl': 'https://content.guardianapis.com/business/2023/apr/30/time-running-out-for-us-financial-firms-to-bid-for-ailing-bank-first-republic', 'isHosted': False, 'pillarId': 'pillar/news', 'pillarName': 'News'}, {'id': 'business/2023/mar/16/first-republic-bank-rescued-latest', 'type': 'article', 'sectionId': 'business', 'sectionName': 'Business', 'webPublicationDate': '2023-03-16T20:47:48Z', 'webTitle': 'US banks launch $30bn rescue of First Republic to stem spiraling crisis ', 'webUrl': 'https://www.theguardian.com/business/2023/mar/16/first-republic-bank-rescued-latest', 'apiUrl': 'https://content.guardianapis.com/business/2023/mar/16/first-republic-bank-rescued-latest', 'isHosted': False, 'pillarId': 'pillar/news', 'pillarName': 'News'}, {'id': 'business/2023/mar/16/first-republic-biggest-us-banks-weigh-rescue', 'type': 'article', 'sectionId': 'business', 'sectionName': 'Business', 'webPublicationDate': '2023-03-16T17:16:38Z', 'webTitle': 'Biggest US banks weigh rescuing First Republic as its shares tumble – report', 'webUrl': 'https://www.theguardian.com/business/2023/mar/16/first-republic-biggest-us-banks-weigh-rescue', 'apiUrl': 'https://content.guardianapis.com/business/2023/mar/16/first-republic-biggest-us-banks-weigh-rescue', 'isHosted': False, 'pillarId': 'pillar/news', 'pillarName': 'News'}, {'id': 'us-news/live/2023/may/01/debt-ceiling-first-republic-bank-biden-republicans-2024-live-updates', 'type': 'liveblog', 'sectionId': 'us-news', 'sectionName': 'US news', 'webPublicationDate': '2023-05-01T20:01:16Z', 'webTitle': 'Biden says banking system is ‘s ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 gdn_res = get_gdn_news_links()
#       2 print(*gdn_res[:10],sep='\n')
#       3 get_news_article_from_link(gdn_res[0]) # test
#
# Cell In[107], line 18, in get_gdn_news_links()
#      15 pages = gdn_data['response']['pages']
#      17 for page in range(1,pages+1):
# ---> 18     gdn = requests.get(f"https://content.guardianapis.com/search?page={page}&q={urllib.parse.quote(q)}&from-date={from_date}&api-key={gdn_api_key}")
#      19     gdn_data = gdn.json()
#      20     for i in range(len(gdn_data['response']['results'])):
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1090 # Force connect early to allow us to validate the connection.
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#    1095     warnings.warn(
#    1096         (
#    1097             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1102         InsecureRequestWarning,
#    1103     )
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:635, in HTTPSConnection.connect(self)
#     626 if is_time_off:
#     627     warnings.warn(
#     628         (
#     629             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     632         SystemTimeWarning,
#     633     )
# --> 635 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     636     sock=sock,
#     637     cert_reqs=self.cert_reqs,
#     638     ssl_version=self.ssl_version,
#     639     ssl_minimum_version=self.ssl_minimum_version,
#     640     ssl_maximum_version=self.ssl_maximum_version,
#     641     ca_certs=self.ca_certs,
#     642     ca_cert_dir=self.ca_cert_dir,
#     643     ca_cert_data=self.ca_cert_data,
#     644     cert_file=self.cert_file,
#     645     key_file=self.key_file,
#     646     key_password=self.key_password,
#     647     server_hostname=server_hostname,
#     648     ssl_context=self.ssl_context,
#     649     tls_in_tls=tls_in_tls,
#     650     assert_hostname=self.assert_hostname,
#     651     assert_fingerprint=self.assert_fingerprint,
#     652 )
#     653 self.sock = sock_and_verified.socket
#     654 self.is_verified = sock_and_verified.is_verified
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:776, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     773     if is_ipaddress(normalized):
#     774         server_hostname = normalized
# --> 776 ssl_sock = ssl_wrap_socket(
#     777     sock=sock,
#     778     keyfile=key_file,
#     779     certfile=cert_file,
#     780     key_password=key_password,
#     781     ca_certs=ca_certs,
#     782     ca_cert_dir=ca_cert_dir,
#     783     ca_cert_data=ca_cert_data,
#     784     server_hostname=server_hostname,
#     785     ssl_context=context,
#     786     tls_in_tls=tls_in_tls,
#     787 )
#     789 try:
#     790     if assert_fingerprint:
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:466, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     463 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     464     pass
# --> 466 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     467 return ssl_sock
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:510, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     507     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     508     return SSLTransport(sock, ssl_context, server_hostname)
# --> 510 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File c:\Users\jordi\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
for result in googleresult:
  try: # Added try-except as not all websites allow scraping
    # print(result['desc'])
    print("---------------------------------------------------------------------------------------------------------------------------------------")
    url = result['link']
    print(url)
    ''' Shreya - There are some links like youtube links that we should avoid summarizing. '''

    if "youtube" in url:
      continue

    ''' TO DO - Also, Let's try to give the first few links from major articles that can be scraped - wsj, reuter, fox, etc. '''

    news = get_news_article_from_link(url) ## Summarize news
    # print("Raw news: \n",news)
    summary_news = summarize_article(news)
    print("Summary news: \n",' '.join(summary_news))
    extracted_keywords = extract_keywords(news) ## Keyword extraction
    print("")
    print("NER:")
    print(extracted_keywords)
    time.sleep(2)
    print('\n\n')
  except:
    pass
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://www.investors.com/market-trend/stock-market-today/market-rally-resilient-after-fed-surprise-tesla-ends-record-run-big-warning-fuels-this-group/
# Summary news:
#  The stock market rally showed resilience Wednesday.  initially gave up ground on a surprisingly hawkish Federal Reserve rate-hike outlook. But closed mixed on relatively dovish comments from Fed chief Jerome Powell. Dow Jones futures tilted higher after hours, along with S&P 500 futures and Nasdaq futures.  Nvidia (NVDA) rose to a record high, a day after closing above a $1 trillion market cap.
# federal reserve ORG
# fed ORG
# jerome powell PER
# dow jones MISC
# s MISC
# & p ORG
# 500 MISC
# nasdaq MISC
# fed ORG
# fed ORG
# jerome powell PER
# nvidia ORG
# nvda ORG
# tesla ORG
# tsla ORG
# lennar ORG
# len ORG
# dow jones MISC
# unitedhealth ORG
# unh ORG
# shockwave medical ORG
# swav ORG
# dexcom ORG
# dxcm ORG
# edwards lifesciences ORG
# ew ORG
# smith & nephew ORG
# snn ORG
# stryker ORG
# syk ORG
# zimmer biomet holdings ORG
# zbh ORG
# boston scientific ORG
# bsx ORG
# inmode ORG
# inmd ORG
# swav ORG
# tesla ORG
# nvidia ORG
# ibd MISC
# swav ORG
# ibd MISC
# tsla ORG
# ibd MISC
# dow jones MISC
# dow jones MISC
# s & p ORG
# 500 MISC
# nasdaq 100 MISC
# dow MISC
# fed ORG
# fed ORG
# fed ORG
# fed ORG
# fed ORG
# fed ORG
# powell PER
#
# NER:
# ['']
#
#
#
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://www.foxbusiness.com/markets/tesla-valuation-240b-13-day-winning-streak
# Summary news:
#  Tesla’s market value has grown by almost a quarter-billion dollars while closing with a gain the last 13 sessions on Wall Street. Shares for the EV maker have now more than doubled in 2023, moving roughly 108% higher since Jan 1. Last week, Tesla made changes to its battery supply chain to bring some of its vehicles within the guidelines that would qualify them for federal U.S. credits.
# tesla ORG
# wall street LOC
# ev MISC
# tsla tesla inc ORG
# fox business ORG
# david russell PER
# tradestation group ORG
# tesla ORG
# nasdaq MISC
# elon musk PER
# cybertruck MISC
# roadster MISC
# tesla ORG
# ford ORG
# gm ORG
# china LOC
# us LOC
# tesla ORG
# russell PER
# tesla ORG
# u. s LOC
# . MISC
# model 3 MISC
# toyota camry MISC
# tesla model 3 MISC
# model 3 MISC
# fueleconomy ORG
# gov ORG
# tesla model ys MISC
# model 3 MISC
# california LOC
# ken martin PER
# fox business ORG
#
# NER:
# ['']
#
#
#
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://www.reuters.com/business/autos-transportation/tesla-shares-finally-snap-record-13-day-win-streak-that-added-200-bln-value-2023-06-14/
# Summary news:
#  During the streak, Tesla shares rose by more than 40%, boosting its market value to roughly $814 billion. The gain in market capitalization during the run came to nearly $240 billion - or more than the entire value of Japan's Toyota. The electric carmaker's stock price is still far beyond Wall Street's forecasts, sitting 28% higher than the median target of $200.
# reuters ORG
# tesla ORG
# tsla ORG
# o ORG
# u. s LOC
# tesla ORG
# japan LOC
# toyota ORG
# t ORG
# tesla ORG
# u. s LOC
# ford ORG
# f. n ORG
# general motors ORG
# gm. n ORG
# u. s LOC
# north america LOC
# nacs MISC
# tesla ORG
# wall street LOC
# wall street LOC
# ford ORG
# gm ORG
# tesla ORG
# wedbush ORG
# tesla ORG
# amazon. com ORG
# amzn ORG
# o ORG
# ford ORG
# gm ORG
# eikon ORG
# wedbush ORG
# tesla ORG
# amazon ORG
# tesla ORG
# s3 MISC
# chavi mehta PER
# aditya soni PER
# bengaluru LOC
# david gaffen PER
# maju samuel PER
#
# NER:
# ['']
#
#
#
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://www.barrons.com/articles/stock-market-movers-3ed02039
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://www.dailymail.co.uk/news/article-12195513/California-doctor-drove-Tesla-cliff-wife-children-inside-barred-medicine.html
# Summary news:
#  Dharmesh Patel, 41, has pleaded not guilty to three counts of attempted murder. Radiologist veered off Pacific Coast Highway south of San Francisco in January. His children, aged four and seven, and wife Neha, 41, were in the car. An official said it was an 'absolute miracle' that they made it out alive. Patel has been held in San Mateo County's Maguire Correctional Facility since his arrest. This week the Medical Board of California successfully applied to ban him from practicing medicine if he is released on bail
# california LOC
# tesla MISC
# devil ' s side LOC
# dharmesh patel PER
# tesla model y MISC
# pacific coast highway LOC
# san francisco LOC
# neha patel PER
# patel PER
# san mateo county LOC
# maguire LOC
# facility LOC
# medical board of california ORG
# mercury news ORG
# pasadena LOC
# neha patel PER
# patel PER
# san mateo county LOC
# maguire correctional facility LOC
# patel PER
# tom lantos tunnel LOC
# tesla MISC
# patel PER
# rachel holt PER
# patel PER
# pasadena LOC
# neha patel PER
# california highway patrol ORG
# dharmesh patel PER
# tesla MISC
# patel PER
# joshua bentley PER
# patel PER
# redwood city LOC
# patel PER
# josh bentley PER
#
# NER:
# ['']
#
#
#
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://www.barrons.com/articles/tesla-stock-winning-streak-ev-prices-model-y-elon-musk-fc2d10df
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://finance.yahoo.com/news/tesla-240-billion-rally-set-135539278.html
# Summary news:
#  Tesla Inc. shares snapped their record-setting 13-day winning streak Wednesday. A hawkish stance from the Federal Reserve and market technicals took some steam off the rally. The lightning-quick run through Tuesday had added more than $240 billion to the electric-vehicle maker’s valuation since late May. As if on cue, Tesla shares closed down 0.7% at $256.79 Wednesday, ending their longest-ever run of gains.
# bloomberg ORG
# tesla inc. ORG
# federal reserve ORG
# bloomberg ORG
# tesla ORG
# elon MISC
# musk ORG
# all MISC
# ev ORG
# tesla ORG
# general motors co ORG
# ford motor co ORG
# model 3 MISC
# us MISC
# tesla ORG
# ai MISC
# morgan stanley ORG
# adam jonas PER
# philip sanders PER
# bloomberg businessweek ORG
# bloomberg l. p ORG
#
# NER:
# ['']
#
#
#
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://www.thestreet.com/electric-vehicles/why-tesla-stock-is-going-through-the-roof-and-where-it-could-go-next
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://techcrunch.com/2023/06/14/why-every-ev-charging-network-combined-cant-compete-with-tesla/
# Summary news:
#  Tesla’s fleet is the largest fully electric fleet in the U.S., with around 1.6 million vehicles on the road. Most chargers are located in massive parking lots, usually in a forgotten corner with little in the way of amenities for EV drivers. When they’re in short supply, EV drivers either struggle to find a spot or have to wait in line, sometimes for a while.
# tesla ORG
# ccs MISC
# bay area LOC
# tesla ORG
# tesla ORG
# u. s LOC
# department of energy ORG
# supercharger ORG
#
# NER:
# ['']
#
#
#
# ---------------------------------------------------------------------------------------------------------------------------------------
# https://driveteslacanada.ca/news/tesla-increases-model-y-awd-price-by-250-in-the-us-removes-white-interior-option/
# Summary news:
#  Tesla has tweaked the price of the Model Y in the US, increasing it for the third time since April. The increase affects only the entry-level Model Y AWD, which now starts at $47,740 with standard equipment, a small $250 increase from before. Tesla also removed an option for the Model Y AWD in the US, matching a similar move made in Canada last month. With the option adding an extra $1,000 USD to the purchase price, it could be that the data Tesla has shows the majority of Model Y AWD buyers are sticking with the standard black interior
# tesla ORG
# model y MISC
# us LOC
# model y awd MISC
# tesla ORG
# model y awd MISC
# us LOC
# canada LOC
# model y MISC
# canada LOC
# us LOC
# model y awd MISC
# texas LOC
# tesla ORG
# model y MISC
# canada LOC
# shanghai LOC
# lfp MISC
# model y awd MISC
# us LOC
# model y rwd MISC
# canada LOC
# canada LOC
# tesla ORG
# y awd MISC
# us LOC
# austin LOC
# twitter ORG
# tesla ORG
# model y MISC
# canada LOC
# model y MISC
# us LOC
# tesla ORG
# model y awd MISC
# tesla ORG
# tesla ORG
# model y MISC
# model 3 MISC
#
# NER:
# ['']

# %%
get_news_article_from_link('https://www.comingsoon.net/movies/trailers/1295648-foundation-season-2-trailer-apple-tv')
# Out:
# 'Apple TV+ has released the Foundation Season 2 trailer for the forthcoming return of its sci-fi drama, teasing more action-packed sequences for the next chapter in Hari Seldon’s fight against the Cleons’ Galactic Empire. Season 2 will start streaming on Friday, July 14. The premiere will then be followed by new episodes weekly every Friday through September 15.\n\nThe video features the return of Lee Pace’s Brother Day and Jared Harris‘ Hari Seldon, with the former going all out in destroying Seldon’s Foundation that’s threatening everything he and predecessors have built. It shows Gaal Dornick’s ominous dream about an incoming crisis that’s bigger than the last.\n\nCheck out the Foundation Season 2 trailer below (watch more trailers):\n\nWhat is Foundation about?\n\nApple TV+’s Foundation hails from creator and executive producer David S. Goyer, who is also serving as showrunner. It chronicles the stories of four crucial individuals transcending space and time as they overcome deadly crises, shifting loyalties, and complicated relationships that will ultimately determine the fate of humanity.\n\n“More than a century after the season one finale, tension mounts throughout the galaxy in Foundation season two,” reads the synopsis. “As the Cleons unravel, a vengeful queen plots to destroy Empire from within. Hari, Gaal, and Salvor discover a colony of Mentalics with psionic abilities that threaten to alter psychohistory itself. The Foundation has entered its religious phase, promulgating the Church of Seldon throughout the Outer Reach and inciting the Second Crisis: war with Empire.”\n\nThe series stars Jared Harris as Hari Seldon and Lee Pace as Brother Day along with Lou Llobell as Gaal Dornick, Leah Harvey as Salvor Hardin, Laura Birn as Demerzel, Terrence Mann as Brother Dusk, Cassian Bilton as Brother Dawn, and Alfred Enoch as Raych. Joining them in Season 2 are Holt McCallany, Ben Daniels, Rachel House, Isabella Laughland, Mikael Persbrandt, Kulvinder Ghir, Sandra Yi Sencindiver, Ella-Rae Smith, Dimitri Leonidas, and Nimrat Kaur.\n\nFoundation is executive produced by Robyn Asimov, Josh Friedman, Cameron Welsh, David Ellison, Dana Goldberg, and Bill Bost. It is a co-production between Apple Studios and Skydance Television.'

# %% [markdown]
# Integarted Flow

# %%
## TBD
